# %%
import pandas as pd

data  = { #Dictionary 
    'Text': [ #Keys
        'I love this movie', #values 
        'This movie is amazing',
        'I am so happy today',
        'The service was terrible',
        'I hate waiting in lines',
        'It is an average product',
        'The food is delicious',
        'I am disappointed',
        'Nothing special about this place',
        'I absolutely adore this!'
            ],
        'Sentiment' : [ #keys
        'Positive',#values
        'Positive',
        'Positive',
        'Negative',
        'Negative',
        'Neutral',
        'Positive',
        'Negative',
        'Neutral',
        'Positive'
            ]
}

df = pd.DataFrame(data)

print(data)
# Out:
# {'Text': ['I love this movie', 'This movie is amazing', 'I am so happy today', 'The service was terrible', 'I hate waiting in lines', 'It is an average product', 'The food is delicious', 'I am disappointed', 'Nothing special about this place', 'I absolutely adore this!'], 'Sentiment': ['Positive', 'Positive', 'Positive', 'Negative', 'Negative', 'Neutral', 'Positive', 'Negative', 'Neutral', 'Positive']}
